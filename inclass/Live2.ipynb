# %% [markdown]
# # Unit 2 Code demo

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(0,2*np.pi,100)
y = np.sin(5*x)

# %%
plt.plot(x,y)
plt.ylim(-1.1,1.1)

plt.xlabel('x')
plt.ylabel('y')

plt.savefig("demo.png", facecolor = "gold")

plt.show()
